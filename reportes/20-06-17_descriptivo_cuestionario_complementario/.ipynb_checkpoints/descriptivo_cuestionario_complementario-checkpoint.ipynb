# %% [markdown]
# # Descriptivo general. Cuestionario Complementario

# %%
import os
os.chdir('../../')
#os.chdir('./aprender_cife')

# %%
# %matplotlib inline  
from funciones.exploratorio import (barras_apiladas, tabla_pond, from_to, df, cod, col_div, col_cat, barras_apiladas_setiq, etiquetas, val_lab,
                                    crear_paleta, parse_ylab, anotar_porcentajes, anotar_porcentaje_barras, barras_minimalista,
                                    col_cat_val, col_lab)
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import matplotlib.ticker as mtick

# %% [markdown]
# Definimos algunas funciones para analizar los datos y graficar.

# %% [markdown]
# ## Total de casos

# %%
#df.info()

# %%
df.ponder.size
# Out:
# 316015

# %% [markdown]
# ## Total de casos faltantes

# %%
## Total de nan para cuestionario complementario
df.ponder.isna().sum()
# Out:
# 344

# %% [markdown]
# ## Sociodemográficas

# %%
t = tabla_pond(['ap1'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
t = tabla_pond(['ap2'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
l = from_to('ap3a', 'ap3c')

fig, axs = plt.subplots(3,1, sharex=True, figsize=(10,10))

for i in range(len(l)):
    barras_minimalista(tabla_pond([l[i]]), axs[i])
    axs[i].tick_params(axis='x', which='both', length=0)

# %%
t = tabla_pond(['ap4'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
l = from_to('ap5a', 'ap5h')

l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,7))

color = col_cat(t).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, True)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.07), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %%
t = tabla_pond(['ap6'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
l = from_to('ap7a', 'ap7d')
l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,7))

color = col_cat(t).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, False)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.07), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %%
l = from_to('ap8a', 'ap8g')
l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,7))

color = col_cat(t).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, True)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.07), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %%
t = tabla_pond(['ap9'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
l = from_to('ap10', 'ap11')

fig, axs = plt.subplots(len(l),1, sharex=True, figsize=(10,8))

for i in range(len(l)):
    barras_minimalista(tabla_pond([l[i]]), axs[i])
    axs[i].tick_params(axis='x', which='both', length=0)

# %%
t = tabla_pond(['ap12'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
t = tabla_pond(['ap13'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
t = tabla_pond(['ap14'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
l = from_to('ap15a', 'ap15c')
l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,6))

color = crear_paleta(t, 'Blues', True).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, True)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.07), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %%
l = from_to('ap16', 'ap17')

fig, axs = plt.subplots(len(l),1, sharex=True, figsize=(10,8))

for i in range(len(l)):
    barras_minimalista(tabla_pond([l[i]]), axs[i])
    axs[i].tick_params(axis='x', which='both', length=0)

# %%
### Entre los que trabajan para alguien que no sea parte de la familia...

# %%
## De los que trabajan afuera de la casa?, les pagan?
t = tabla_pond(['ap18'], df=df[df['ap17'] == '1'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %% [markdown]
# ## Antecedentes Escolares

# %%
t = tabla_pond(['ap19'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
l = from_to('ap20', 'ap21')

fig, axs = plt.subplots(len(l),1, sharex=True, figsize=(10,8))

for i in range(len(l)):
    barras_minimalista(tabla_pond([l[i]]), axs[i])
    axs[i].tick_params(axis='x', which='both', length=0)

# %%
t = tabla_pond(['ap22'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
t = tabla_pond(['ap23'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
t = tabla_pond(['ap24'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
t = tabla_pond(['ap25'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
l = from_to('ap26a', 'ap26h')
l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,6))

color = col_cat(t).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, True)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.07), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %%
t = tabla_pond(['ap27'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
t = tabla_pond(['ap28'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
t = tabla_pond(['ap29'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %% [markdown]
# ## Autoconcepto

# %%
l = from_to('ap30a', 'ap30h')
l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,6))

color = col_div(t).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, True)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.07), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %%
l = from_to('ap31a', 'ap31c')
l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,6))

color = crear_paleta(t, 'Blues', True).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, True)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.07), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %%
l = from_to('ap32a', 'ap32c')
l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,6))

color = crear_paleta(t, 'Blues', True).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, True)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.07), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %% [markdown]
# ## Opiniones sobre actividades escolares

# %%
l = from_to('ap33a', 'ap33g')
l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,6))

color = col_cat(t).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, True)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.07), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %%
t = tabla_pond(['ap34a'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
t = tabla_pond(['ap34b'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
l = from_to('ap35a', 'ap35j')
l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,9))

color = crear_paleta(t, 'Blues', True).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, True)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.07), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %%
t = tabla_pond(['ap36'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
l = from_to('ap37a', 'ap37h')
l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,9))

color = col_cat(t).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, True)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.07), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %%
l = from_to('ap38', 'ap40')

fig, axs = plt.subplots(len(l),1, sharex=True, figsize=(10,10))

for i in range(len(l)):
    barras_minimalista(tabla_pond([l[i]]), axs[i])
    axs[i].tick_params(axis='x', which='both', length=0)

# %%
l = from_to('ap41', 'ap43')

fig, axs = plt.subplots(len(l),1, sharex=True, figsize=(10,10))

for i in range(len(l)):
    barras_minimalista(tabla_pond([l[i]]), axs[i])
    axs[i].tick_params(axis='x', which='both', length=0)

# %%
l = from_to('ap44a', 'ap44f')
l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,9))

color = col_cat(t).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, True)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.07), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %%
l = from_to('ap45a', 'ap45i')
l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,9))

color = col_cat(t).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, True)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.07), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %%
l = from_to('ap46a', 'ap46c')

fig, axs = plt.subplots(len(l),1, sharex=True, figsize=(10,10))

for i in range(len(l)):
    barras_minimalista(tabla_pond([l[i]]), axs[i])
    axs[i].tick_params(axis='x', which='both', length=0)

# %%
t = tabla_pond(['ap47'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
l = from_to('ap48a', 'ap48c')
l = l[::-1]    
t=tabla_pond(l)
fig, ax = plt.subplots(figsize=(10,5))

color = col_div(t).values
barras_apiladas_setiq(t, ax, color)

colnames, valnames = etiquetas(t)
#valnames = valnames.reindex(t.index)

colnames = parse_ylab(colnames, True)
ax.set_yticklabels(colnames.label)

#fig.subplots_adjust(bottom=0.1)
ax.legend(valnames['Etiqueta.1'], loc='upper center', bbox_to_anchor=(0.5, -0.1), frameon=False,
              shadow=False, ncol=len(valnames['Etiqueta.1']))

ax.set(title=colnames.title[0],
          ylabel='',
          xlabel='Porcentaje de estudiantes',
          xlim=(0,1))

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)  

## Visualizamos las proporciones como porcentajes
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))

fig.tight_layout()

anotar_porcentajes(ax)

# %%
t = tabla_pond(['ap49'])
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
from pandas.api.types import CategoricalDtype
t = tabla_pond(['cod_provincia'])

c = CategoricalDtype(t.iloc[:,0].sort_values(ascending=False).index.values.tolist(), ordered=True)
t.index = t.index.astype(c)

t.iloc[:,0].sort_values(ascending=False).index
fig, ax = plt.subplots(figsize=(10,6))
barras_minimalista(t, ax)

# %%
t = tabla_pond(['sector'])
fig, ax = plt.subplots(figsize=(10,4))
barras_minimalista(t, ax)

# %%
t = tabla_pond(['ambito'])
fig, ax = plt.subplots(figsize=(10,4))
barras_minimalista(t, ax)
